# %%
import sympy as sp

# %%
expr = sp.exp(-sp.Rational(1,2))*(1+sp.exp(-1))/(1-sp.exp(-1))**2
expr = sp.Rational(1,2)* expr*(2*sp.sinh(sp.Rational(1,2)))
expr
# Out:
# (exp(-1) + 1)*exp(-1/2)*sinh(1/2)/(1 - exp(-1))**2

# %%
sp.N(expr)
# Out:
# 1.08197670686933

# %%
expr.simplify()
# Out:
# (1 + E)*exp(1/2)*sinh(1/2)/(1 - E)**2

# %%
expr_2 = (1 - sp.exp(-2))/(1-sp.exp(-1))**2 * sp.Rational(1,2)
sp.N(expr_2)
# Out:
# 1.08197670686933

# %%
expr_2
# Out:
# (1 - exp(-2))/(2*(1 - exp(-1))**2)

# %%
(expr_2 - expr)
# Out:
# -(exp(-1) + 1)*exp(-1/2)*sinh(1/2)/(1 - exp(-1))**2 + (1 - exp(-2))/(2*(1 - exp(-1))**2)

# %%
half = sp.Rational(1,2)
expr = sp.exp(-sp.Rational(1,2))*(1+sp.exp(-1))/(1-sp.exp(-1))**2
expr_1 = half *expr*(sp.exp(half)-sp.exp(-half))
