# %%
import importlib

import plotting_funcs

# %%
importlib.reload(plotting_funcs)
# Out:
# <module 'plotting_funcs' from 'C:\\Users\\Taner\\Desktop\\QFPE\\QFPE\\QFPE\\plotting_funcs.py'>

# %%
plotting_funcs.sci_formatter(1, 0, 7)
# Out:
# '1.0$\\times 10^-7$'
